# %% [markdown]
# # 📊 Parcial – Análisis de Redes Sociales (Primer Corte)
#
# ## 🎯 Objetivo
# Evaluar tu dominio de **filtros** y **agrupaciones** en Python (sin pivots ni gráficos) y tu capacidad de **análisis de negocio** en métricas de marketing: **CAC, LTV, churn rate, funnel, unit economics (LTV/CAC)**.
#
# ---
# ## 🧩 Contexto de Negocio (Caso Real)
# **StartUp SaaS en crecimiento.** Vende planes **Basic, Pro, Enterprise** en **LatAm, North America, Europe, APAC**. Los canales de adquisición son: **meta_ads, google_ads, organic_search, outbound_sales**. Los usuarios se registran por **web** o **mobile_app**.
#
# La dirección quiere decidir **dónde invertir el presupuesto del próximo trimestre**. Te piden:
#
# 1) Identificar **canales más rentables** (relación **LTV/CAC** y churn).
# 2) Detectar **regiones** con mayor **potencial de crecimiento** y/o **riesgo**.
# 3) Evaluar el desempeño por **tier** (Basic, Pro, Enterprise).
# 4) Recomendar **asignación de presupuesto** por **canal + tier**.
#
# ---
# ## 📂 Instrucciones
# - Trabaja únicamente con **filtros** y **agrupaciones**. **No uses** tablas dinámicas (pivot), merges ni gráficos.
# - Archivo a usar: `clientes_marketing.csv`.
# - Escribe **código + interpretación breve** para cada inciso.
# - Si el enunciado dice **“Agrupa”**, usa `groupby`. Si dice **“Filtra”**, usa filtrado con máscaras booleanas. Si dice **“Ambas”**, realiza primero el **filtro** y luego la **agrupación**.
#
# ---

# %% [markdown]
# ## Descargar Tabla (Correr una vez)

# %%
# !wget https://github.com/javierherrera1996/IntroMarketingAnalytics/raw/refs/heads/main/PrimerCorte/cac_ltv_model.csv
# Out:
# --2025-09-18 00:19:36--  https://github.com/javierherrera1996/IntroMarketingAnalytics/raw/refs/heads/main/PrimerCorte/cac_ltv_model.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/javierherrera1996/IntroMarketingAnalytics/refs/heads/main/PrimerCorte/cac_ltv_model.csv [following]
# --2025-09-18 00:19:37--  https://raw.githubusercontent.com/javierherrera1996/IntroMarketingAnalytics/refs/heads/main/PrimerCorte/cac_ltv_model.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 661398 (646K) [text/plain]
# Saving to: ‘cac_ltv_model.csv.1’
#
# cac_ltv_model.csv.1 100%[===================>] 645.90K  --.-KB/s    in 0.05s
#
# 2025-09-18 00:19:37 (11.9 MB/s) - ‘cac_ltv_model.csv.1’ saved [661398/661398]

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# 1) Cargar Dataset
data = pd.read_csv('cac_ltv_model.csv')

# %% [markdown]
# ### ✅ Variables relevantes (recordatorio)
# - `acquisition_channel`, `signup_source`, `region`, `customer_tier`
# - `plan_price`, `discount_rate`, `arpu`, `gross_margin`, `churn_rate`
# - `contract_length_months`, `marketing_spend`
#
# ### 🧮 Fórmulas de negocio (a usar en el examen)
# - **CAC por canal**:
#     $$ CAC = \frac{\text{Total Marketing Spend}}{\text{Clientes adquiridos}} $$
#
# - **LTV por observación** (aprox.):
#    $$ LTV = ARPU \times contract\_length\_months \times gross\_margin \times (1 - churn\_rate) $$
#
# - **Unit economics**:
#   $$ LTV/CAC   $$(ideal \> 3 como regla general de SaaS)
#
# ---

# %% [markdown]
# ### Parte Exploratoria: Cree una muestra de los primeros 5 elementos de esta tabla. ¿Cuantas observaciones tienes?

# %%
data.head()
# Out:
#    year  month    date  customer_id acquisition_channel signup_source  \
# 0  2023      1  Jan-23         1001      outbound_sales           web
# 1  2023      1  Jan-23         1002            meta_ads           web
# 2  2023      1  Jan-23         1003      organic_search    mobile_app
# 3  2023      1  Jan-23         1004      organic_search           web
# 4  2023      1  Jan-23         1005      organic_search           web
#
#           region customer_tier  plan_price  discount_rate   arpu  \
# 0  North America         Basic       78.84           0.10  63.63
# 1          LatAm           Pro      120.23           0.00 124.47
# 2  North America    Enterprise      335.82           0.20 278.20
# 3         Europe           Pro      193.89           0.10 190.65
# 4           APAC    Enterprise      471.80           0.10 445.32
#
#    gross_margin  churn_rate  contract_length_months  marketing_spend
# 0          0.76        0.02                      12           212.48
# 1          0.84        0.05                       1           352.60
# 2          0.81        0.02                      12            55.40
# 3          0.80        0.08                       1            49.10
# 4          0.80        0.08                       1            45.27
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['customer_id'].plot(kind='hist', bins=20, title='customer_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['plan_price'].plot(kind='hist', bins=20, title='plan_price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['discount_rate'].plot(kind='hist', bins=20, title='discount_rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['arpu'].plot(kind='hist', bins=20, title='arpu')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('acquisition_channel').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('signup_source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('customer_tier').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='customer_id', y='plan_price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='plan_price', y='discount_rate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='discount_rate', y='arpu', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='arpu', y='gross_margin', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('acquisition_channel')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='acquisition_channel', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('signup_source')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='signup_source', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('region')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='region', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('customer_tier')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='customer_tier', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('plan_price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['plan_price'].plot(kind='line', figsize=(8, 4), title='plan_price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['discount_rate'].plot(kind='line', figsize=(8, 4), title='discount_rate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['arpu'].plot(kind='line', figsize=(8, 4), title='arpu')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['signup_source'].value_counts()
#     for x_label, grp in _df_20.groupby('acquisition_channel')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('acquisition_channel')
# _ = plt.ylabel('signup_source')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['region'].value_counts()
#     for x_label, grp in _df_21.groupby('signup_source')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('signup_source')
# _ = plt.ylabel('region')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['customer_tier'].value_counts()
#     for x_label, grp in _df_22.groupby('region')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('region')
# _ = plt.ylabel('customer_tier')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['acquisition_channel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='customer_id', y='acquisition_channel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['signup_source'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='customer_id', y='signup_source', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='customer_id', y='region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['customer_tier'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='customer_id', y='customer_tier', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['customer_id'].plot(kind='hist', bins=20, title='customer_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['plan_price'].plot(kind='hist', bins=20, title='plan_price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['discount_rate'].plot(kind='hist', bins=20, title='discount_rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('acquisition_channel').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_32.groupby('signup_source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_33.groupby('region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_34.groupby('customer_tier').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35.plot(kind='scatter', x='index', y='customer_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36.plot(kind='scatter', x='customer_id', y='plan_price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37.plot(kind='scatter', x='plan_price', y='discount_rate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38.plot(kind='scatter', x='discount_rate', y='arpu', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_39.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('acquisition_channel')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='acquisition_channel', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_40.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('signup_source')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='signup_source', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_41.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('region')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='region', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('plan_price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['plan_price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_42.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('customer_tier')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='customer_tier', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('plan_price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_43['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_44['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['plan_price'].plot(kind='line', figsize=(8, 4), title='plan_price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['discount_rate'].plot(kind='line', figsize=(8, 4), title='discount_rate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['signup_source'].value_counts()
#     for x_label, grp in _df_47.groupby('acquisition_channel')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('acquisition_channel')
# _ = plt.ylabel('signup_source')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['region'].value_counts()
#     for x_label, grp in _df_48.groupby('signup_source')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('signup_source')
# _ = plt.ylabel('region')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['customer_tier'].value_counts()
#     for x_label, grp in _df_49.groupby('region')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('region')
# _ = plt.ylabel('customer_tier')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_50['acquisition_channel'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_50, x='index', y='acquisition_channel', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_51['signup_source'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_51, x='index', y='signup_source', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_52['region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_52, x='index', y='region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_53['customer_tier'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_53, x='index', y='customer_tier', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
data.shape
# Out:
# (7057, 15)

# %% [markdown]
# ## 🔎 Parte A – Filtros
#
# hint: Crea una tabla con el filtro y luego agrupa la variable que te piden.
#
# 1. **Filtra** los clientes del canal **`meta_ads`**. Calcula el **ARPU promedio** de este subconjunto.

# %%
ClientesMeta = data[data['acquisition_channel'] =='meta_ads']
ClientesMeta['arpu'].mean()
# Out:
# np.float64(168.78858272162617)

# %% [markdown]
# 2. **Filtra** clientes de **LatAm** con **`churn_rate > 0.05`**. ¿Cuántos son? ¿Cuál es su **ARPU promedio**?

# %%
ClientesLatAm = data[data['region'] == 'LatAm']
ClientesLatAmR = ClientesLatAm[ClientesLatAm['churn_rate'] > 0.05]
print(f"Number of customers in LatAm with churn rate > 0.05: {ClientesLatAmR.shape[0]}")
print(f"Average ARPU for these customers: {ClientesLatAmR['arpu'].mean():,.2f}")
# Out:
# Number of customers in LatAm with churn rate > 0.05: 410
# Average ARPU for these customers: 174.78

# %% [markdown]
# 3. **Filtra** clientes **Enterprise** con `contract_length_months > 6`. ¿Cuál es su **gross_margin promedio**?

# %%
ClientesEnterprise = data[data['customer_tier'] == 'Enterprise']
EnterpriseMonths = ClientesEnterprise[ClientesEnterprise['contract_length_months']>6]
EnterpriseMonths ['gross_margin'].mean()
# Out:
# np.float64(0.8248397435897435)

# %% [markdown]
# ## 📊 Parte B – Agrupaciones (SOLO agrupar)
# 4. **Agrupa** por `acquisition_channel` y calcula **ARPU promedio**. Ordena de mayor a menor.

# %%
groupby = data.groupby('acquisition_channel')
groupby['arpu'].mean().sort_values(ascending=False)
# Out:
# acquisition_channel
# outbound_sales   173.61
# google_ads       172.37
# organic_search   171.14
# meta_ads         168.79
# Name: arpu, dtype: float64

# %% [markdown]
# 5. **Agrupa** por `region` y calcula **churn_rate promedio**. Identifica la región con mayor churn.

# %%
groupby = data.groupby('region')
groupby['churn_rate'].mean().sort_values(ascending=False)
# Out:
# region
# Middle East     0.05
# LatAm           0.05
# North America   0.05
# APAC            0.05
# Europe          0.05
# Africa          0.05
# Name: churn_rate, dtype: float64

# %% [markdown]
# 6. **Agrupa** por `customer_tier` y calcula **marketing_spend total**. ¿Cuál tier consume más presupuesto?

# %%
groupby = data.groupby('customer_tier')
groupby['marketing_spend'].sum().sort_values(ascending=False)
# Out:
# customer_tier
# Pro          589,265.04
# Basic        584,419.11
# Enterprise   584,348.87
# Name: marketing_spend, dtype: float64

# %% [markdown]
# ## 🔀 Parte C – Filtro **y** Agrupación (Ambas)
# 7. **Filtra** solo registros de **`signup_source = 'web'`** y luego **agrupa** por `acquisition_channel` para obtener el **churn_rate promedio**.

# %%
Clientesapp = data[data['signup_source'] == 'web']
Clientesapp = data.groupby('acquisition_channel')['churn_rate'].mean()
groupby['churn_rate'].mean()
# Out:
# region
# APAC            0.05
# Africa          0.05
# Europe          0.05
# LatAm           0.05
# Middle East     0.05
# North America   0.05
# Name: churn_rate, dtype: float64

# %% [markdown]
# 8. **Filtra** solo **`mobile_app`** y luego **agrupa** por `region` para calcular **ARPU promedio**.

# %%
Clientesapp = data[data['signup_source'] == 'mobile_app']
Clientesapp.groupby('region')['arpu'].mean()
# Out:
# region
# APAC            169.09
# Africa          172.60
# Europe          165.89
# LatAm           173.20
# Middle East     171.71
# North America   174.00
# Name: arpu, dtype: float64

# %% [markdown]
# 9. **Filtra** a clientes **`Pro`** y **agrupa** por `acquisition_channel` para calcular **marketing_spend total**.

# %%
ClientesPro = data[data['customer_tier'] == 'Pro']
GastoMTotal=ClientesPro.groupby('acquisition_channel')['marketing_spend'].sum()
GastoMTotal.sort_values(ascending=False)
# Out:
# acquisition_channel
# google_ads       226,721.68
# meta_ads         211,517.60
# outbound_sales   121,177.04
# organic_search    29,848.72
# Name: marketing_spend, dtype: float64

# %% [markdown]
# ## 📈 Parte D – Métricas de negocio (CAC, LTV, LTV/CAC)
# 10. **CAC por canal (Agrupa)**: calcula el CAC de cada `acquisition_channel` como:
#    `CAC = marketing_spend_total_del_canal / #clientes_del_canal`

# %%
CanalCAC = data.groupby('acquisition_channel')['marketing_spend'].sum() / data.groupby('acquisition_channel')['customer_id'].count()
CanalCAC.sort_values(ascending=False)
# Out:
# acquisition_channel
# google_ads       401.02
# meta_ads         349.27
# outbound_sales   200.22
# organic_search    49.95
# dtype: float64

# %% [markdown]
# 11. **CAC por tier (Agrupa)**: calcula el CAC de cada `customer_tier` como:
#    `CAC = marketing_spend_total_del_tier / #clientes_del_canal`

# %%
data.groupby('customer_tier')['marketing_spend'].sum() / data.groupby('customer_tier')['customer_id'].count()
# Out:
# customer_tier
# Basic        249.75
# Enterprise   249.19
# Pro          248.43
# dtype: float64

# %% [markdown]
# 12. **LTV por tier (Ambas)**: crea una columna `ltv_individual` con la fórmula dada.

# %%
LTV = data['arpu'] * data['contract_length_months'] * data['gross_margin'] * (1 - data['churn_rate'])
data['ltv_individual'] = LTV

# %% [markdown]
# 12. A. Luego **agrupa** `ltv_individual` por
# `acquisition_channel` para obtener el **LTV promedio**.

# %%
ltvpromedio = data.groupby('acquisition_channel')['ltv_individual'].mean()
ltvpromedio.sort_values(ascending=False)
# Out:
# acquisition_channel
# organic_search   765.13
# outbound_sales   751.57
# meta_ads         729.05
# google_ads       710.25
# Name: ltv_individual, dtype: float64

# %% [markdown]
# 12. B. Luego **agrupa** `ltv_individual`por `customer_tier` para obtener el **LTV promedio**.

# %%
ltvpromedio = data.groupby('customer_tier')['ltv_individual'].mean()
ltvpromedio.sort_values(ascending=False)
# Out:
# customer_tier
# Enterprise   1,349.02
# Pro            577.63
# Basic          291.77
# Name: ltv_individual, dtype: float64

# %% [markdown]
# 13. **Unit economics (Ambas)**: combina tus resultados para comparar **LTV promedio por tier** contra **CAC por canal** y comenta **qué combinaciones canal + tier** lucen más saludables (busca **LTV/CAC > 3**).

# %%
Uniteconomics = data.groupby('acquisition_channel')['ltv_individual'].mean() / data.groupby('acquisition_channel')['marketing_spend'].mean()
Uniteconomics.sort_values(ascending=False)
# Out:
# acquisition_channel
# organic_search   15.32
# outbound_sales    3.75
# meta_ads          2.09
# google_ads        1.77
# dtype: float64

# %% [markdown]
# ## 🧠 Parte E – Análisis crítico (respuesta abierta)
# 13. **CMO por un día**: con tus resultados, ¿en qué **canal(es)** invertirías más el próximo trimestre? ¿Por qué? (Cita **CAC** y **churn**).
# 14. ¿Qué **región** ves con mayor riesgo? ¿Qué hipótesis explicarían su **churn**?
# 15. Identifica **dos combinaciones canal + tier** con mejor **LTV/CAC** y propón **dos acciones** concretas de optimización (p. ej., creatividades, audiencias, pricing, retención).
#
# ---
# ✍️ **Nota**: Mantente disciplinado con el enunciado (**Filtra**, **Agrupa**, **Ambas**). La evaluación pondera **correctitud técnica** y **calidad de interpretación de negocio**.

# %% [markdown]
# 13. Invertiría en ventas a través de google_ads ya que es el canal más fuerte y que tiene más influencia en los clientes pro  y que puede ser complementado a través de meta ads. Los clientes pro tienen más facilidad de llegar a través de los anuncios en google, vienen de allí los clientes que mantienen la fidelidad y necesitan de un servicio especializado
# 14. Todas las regiones tienen el mismo riegsgo, 0.05 es el valor que todos agrupan y que demuestran que puede haber variaciones en la tasa de abandono lo cual evidencia que el país o superficie no influye en el riesgo de inversión
# 15. Mantener las búsquedas orgánicas debe ser prioridad en el sistema de negocio ya que asegura un margen alto dentro de las posibilidades de canales de adquisición, a partir de esto y basados en los datos de customer_tier, el enterprise puede combinarse con las búsquedas orgánicas y así profundizar en la fidelidad del cliente. La llegada de nuevos clientes a través de lo orgánico le brinda superioridad al negocio, dándole características de valor agregado y diferenciandose de la competencia
